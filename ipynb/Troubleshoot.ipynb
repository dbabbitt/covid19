# %%
# !pwd
# Out:
# C:\Users\dev\Documents\repositories\notebooks\Miscellaneous\ipynb

# %%
# !jupyter troubleshoot --format=columns
# Out:
# $PATH:
# 	C:\Users\dev\anaconda3
# 	C:\Users\dev\anaconda3\Library\mingw-w64\bin
# 	C:\Users\dev\anaconda3\Library\usr\bin
# 	C:\Users\dev\anaconda3\Library\bin
# 	C:\Users\dev\anaconda3\Scripts
# 	C:\Program Files (x86)\Common Files\Oracle\Java\javapath
# 	C:\ffmpeg\bin
# 	C:\ProgramData\Oracle\Java\javapath
# 	C:\Windows\system32
# 	C:\Windows
# 	C:\Windows\System32\Wbem
# 	C:\Windows\System32\WindowsPowerShell\v1.0\
# 	C:\Users\dev\AppData\Local\Microsoft\WindowsApps
# 	C:\Users\dev\AppData\Local\GitHubDesktop\bin
# 	C:\WINDOWS\system32
# 	C:\WINDOWS
# 	C:\WINDOWS\System32\Wbem
# 	C:\WINDOWS\System32\WindowsPowerShell\v1.0\
# 	C:\WINDOWS\System32\OpenSSH\
# 	C:\Program Files\MiKTeX 2.9\miktex\bin\x64\
# 	C:\Program Files\dotnet\
# 	C:\libav\usr\bin
# 	C:\Program Files (x86)\Microsoft Visual Studio 14.0
# 	C:\ProgramData\chocolatey\bin
# 	C:\Program Files\nodejs\
# 	C:\Program Files (x86)\Gow\bin
# 	C:\Program Files\PowerShell\7\
# 	C:\Program Files\Git\cmd
# 	C:\Users\dev\anaconda3
# 	C:\Users\dev\anaconda3\Library\mingw-w64\bin
# 	C:\Users\dev\anaconda3\Library\usr\bin
# 	C:\Users\dev\anaconda3\Library\bin
# 	C:\Users\dev\anaconda3\Scripts
# 	C:\Program Files (x86)\Nmap
# 	C:\Users\dev\AppData\Roaming\npm
#
# sys.path:
# 	C:\Users\dev\anaconda3\Scripts
# 	C:\Users\dev\anaconda3\python37.zip
# 	C:\Users\dev\anaconda3\DLLs
# 	C:\Users\dev\anaconda3\lib
# 	C:\Users\dev\anaconda3
# 	C:\Users\dev\anaconda3\lib\site-packages
# 	C:\Users\dev\anaconda3\lib\site-packages\win32
# 	C:\Users\dev\anaconda3\lib\site-packages\win32\lib
# 	C:\Users\dev\anaconda3\lib\site-packages\Pythonwin
#
# sys.executable:
# 	C:\Users\dev\anaconda3\python.exe
#
# sys.version:
# 	3.7.8 | packaged by conda-forge | (default, Jul 31 2020, 01:53:57) [MSC v.1916 64 bit (AMD64)]
#
# platform.platform():
# 	Windows-10-10.0.19041-SP0
#
# where jupyter:
# 	C:\Users\dev\anaconda3\Scripts\jupyter.exe
#
# pip list:
# 	Package                            Version
#
# 	---------------------------------- -------------------
#
# 	alabaster                          0.7.12
#
# 	anaconda-client                    1.7.2
#
# 	anaconda-navigator                 1.10.0
#
# 	anaconda-project                   0.8.3
#
# 	argh                               0.26.2
#
# 	argon2-cffi                        20.1.0
#
# 	asn1crypto                         1.4.0
#
# 	astroid                            2.4.2
#
# 	astropy                            4.1
#
# 	async-generator                    1.10
#
# 	atomicwrites                       1.4.0
#
# 	attrs                              20.2.0
#
# 	autopep8                           1.5.4
#
# 	Babel                              2.8.0
#
# 	backcall                           0.2.0
#
# 	backports.functools-lru-cache      1.6.1
#
# 	backports.shutil-get-terminal-size 1.0.0
#
# 	bcrypt                             3.2.0
#
# 	beautifulsoup4                     4.9.3
#
# 	bitarray                           1.6.0
#
# 	bkcharts                           0.2
#
# 	bleach                             3.2.1
#
# 	bokeh                              2.2.3
#
# 	boto                               2.49.0
#
# 	Bottleneck                         1.3.2
#
# 	brotlipy                           0.7.0
#
# 	certifi                            2020.6.20
#
# 	cffi                               1.14.3
#
# 	chardet                            3.0.4
#
# 	click                              7.1.2
#
# 	cloudpickle                        1.6.0
#
# 	clyent                             1.2.2
#
# 	colorama                           0.4.4
#
# 	comtypes                           1.1.7
#
# 	conda                              4.9.0
#
# 	conda-build                        3.20.5
#
# 	conda-package-handling             1.7.2
#
# 	conda-verify                       3.1.1
#
# 	contextlib2                        0.6.0.post1
#
# 	cryptography                       3.2.1
#
# 	cycler                             0.10.0
#
# 	Cython                             0.29.21
#
# 	cytoolz                            0.11.0
#
# 	dask                               2.30.0
#
# 	decorator                          4.4.2
#
# 	defusedxml                         0.6.0
#
# 	diff-match-patch                   20200713
#
# 	distributed                        2.30.1
#
# 	docutils                           0.16
#
# 	entrypoints                        0.3
#
# 	et-xmlfile                         1.0.1
#
# 	fastcache                          1.1.0
#
# 	filelock                           3.0.12
#
# 	flake8                             3.8.4
#
# 	Flask                              1.1.2
#
# 	fsspec                             0.8.4
#
# 	future                             0.18.2
#
# 	gevent                             20.9.0
#
# 	glob2                              0.7
#
# 	gmpy2                              2.1.0b1
#
# 	greenlet                           0.4.17
#
# 	h5py                               2.10.0
#
# 	HeapDict                           1.0.1
#
# 	html5lib                           1.1
#
# 	idna                               2.10
#
# 	imagecodecs                        2020.5.30
#
# 	imageio                            2.9.0
#
# 	imagesize                          1.2.0
#
# 	importlib-metadata                 2.0.0
#
# 	indeed                             0.0.4
#
# 	iniconfig                          1.1.1
#
# 	intervaltree                       3.0.2
#
# 	ipykernel                          5.3.4
#
# 	ipython                            7.19.0
#
# 	ipython-genutils                   0.2.0
#
# 	ipywidgets                         7.5.1
#
# 	isort                              5.6.4
#
# 	itsdangerous                       1.1.0
#
# 	jdcal                              1.4.1
#
# 	jedi                               0.14.1
#
# 	Jinja2                             2.11.2
#
# 	joblib                             0.17.0
#
# 	json5                              0.9.5
#
# 	jsonschema                         3.2.0
#
# 	jupyter-client                     6.1.7
#
# 	jupyter-console                    6.2.0
#
# 	jupyter-core                       4.6.3
#
# 	jupyterlab                         2.2.9
#
# 	jupyterlab-pygments                0.1.2
#
# 	jupyterlab-server                  1.2.0
#
# 	keyring                            21.4.0
#
# 	kiwisolver                         1.3.1
#
# 	lazy-object-proxy                  1.4.3
#
# 	libarchive-c                       2.9
#
# 	llvmlite                           0.34.0
#
# 	locket                             0.2.0
#
# 	lxml                               4.6.1
#
# 	MarkupSafe                         1.1.1
#
# 	matplotlib                         3.3.2
#
# 	mccabe                             0.6.1
#
# 	menuinst                           1.4.16
#
# 	mistune                            0.8.4
#
# 	mkl-fft                            1.2.0
#
# 	mkl-random                         1.2.0
#
# 	mkl-service                        2.3.0
#
# 	mock                               4.0.2
#
# 	more-itertools                     8.6.0
#
# 	mpmath                             1.1.0
#
# 	msgpack                            1.0.0
#
# 	multipledispatch                   0.6.0
#
# 	navigator-updater                  0.2.1
#
# 	nbclient                           0.5.1
#
# 	nbconvert                          6.0.7
#
# 	nbformat                           5.0.8
#
# 	nest-asyncio                       1.4.2
#
# 	networkx                           2.5
#
# 	nltk                               3.4.4
#
# 	nose                               1.3.7
#
# 	notebook                           6.1.4
#
# 	numba                              0.51.2
#
# 	numexpr                            2.7.1
#
# 	numpy                              1.19.4
#
# 	numpydoc                           1.1.0
#
# 	olefile                            0.46
#
# 	openpyxl                           3.0.5
#
# 	packaging                          20.4
#
# 	pandas                             1.1.4
#
# 	pandocfilters                      1.4.2
#
# 	paramiko                           2.7.2
#
# 	parso                              0.5.2
#
# 	partd                              1.1.0
#
# 	path                               15.0.0
#
# 	pathlib2                           2.3.5
#
# 	pathtools                          0.1.2
#
# 	patsy                              0.5.1
#
# 	pep8                               1.7.1
#
# 	pexpect                            4.8.0
#
# 	pickleshare                        0.7.5
#
# 	Pillow                             8.0.1
#
# 	pip                                20.2.4
#
# 	pkginfo                            1.6.1
#
# 	pluggy                             0.13.1
#
# 	ply                                3.11
#
# 	prometheus-client                  0.8.0
#
# 	prompt-toolkit                     3.0.8
#
# 	psutil                             5.7.3
#
# 	ptyprocess                         0.6.0
#
# 	py                                 1.9.0
#
# 	pycodestyle                        2.6.0
#
# 	pycosat                            0.6.3
#
# 	pycparser                          2.20
#
# 	pycrypto                           2.6.1
#
# 	pycurl                             7.43.0.6
#
# 	pydocstyle                         5.1.1
#
# 	pydub                              0.24.1
#
# 	pyflakes                           2.2.0
#
# 	Pygments                           2.7.2
#
# 	pylint                             2.6.0
#
# 	PyNaCl                             1.4.0
#
# 	pyodbc                             4.0.30
#
# 	pyOpenSSL                          19.1.0
#
# 	pyparsing                          2.4.7
#
# 	Pyphen                             0.9.5
#
# 	PyQt5                              5.12.3
#
# 	PyQt5-sip                          4.19.18
#
# 	PyQtChart                          5.12
#
# 	PyQtWebEngine                      5.12.1
#
# 	pyreadline                         2.1
#
# 	pyrsistent                         0.17.3
#
# 	PySocks                            1.7.1
#
# 	pytest                             6.1.2
#
# 	python-dateutil                    2.8.1
#
# 	python-jsonrpc-server              0.4.0
#
# 	python-language-server             0.31.7
#
# 	pytz                               2020.4
#
# 	PyWavelets                         1.1.1
#
# 	pywin32                            228
#
# 	pywin32-ctypes                     0.2.0
#
# 	pywinpty                           0.5.7
#
# 	PyYAML                             5.3.1
#
# 	pyzmq                              19.0.2
#
# 	QDarkStyle                         2.8.1
#
# 	QtAwesome                          1.0.1
#
# 	qtconsole                          4.7.7
#
# 	QtPy                               1.9.0
#
# 	regex                              2020.10.28
#
# 	requests                           2.24.0
#
# 	rope                               0.18.0
#
# 	Rtree                              0.9.4
#
# 	ruamel-yaml-conda                  0.15.80
#
# 	scikit-image                       0.17.2
#
# 	scikit-learn                       0.23.2
#
# 	scipy                              1.5.3
#
# 	seaborn                            0.11.0
#
# 	selenium                           3.141.0
#
# 	Send2Trash                         1.5.0
#
# 	setuptools                         49.6.0.post20201009
#
# 	simplegeneric                      0.8.1
#
# 	singledispatch                     3.4.0.3
#
# 	sip                                4.19.24
#
# 	six                                1.15.0
#
# 	snowballstemmer                    2.0.0
#
# 	sortedcollections                  1.2.1
#
# 	sortedcontainers                   2.2.2
#
# 	soupsieve                          2.0.1
#
# 	Sphinx                             3.3.0
#
# 	sphinxcontrib-applehelp            1.0.2
#
# 	sphinxcontrib-devhelp              1.0.2
#
# 	sphinxcontrib-htmlhelp             1.0.3
#
# 	sphinxcontrib-jsmath               1.0.1
#
# 	sphinxcontrib-qthelp               1.0.3
#
# 	sphinxcontrib-serializinghtml      1.1.4
#
# 	sphinxcontrib-websupport           1.2.4
#
# 	spyder                             4.0.1
#
# 	spyder-kernels                     1.8.1
#
# 	SQLAlchemy                         1.3.20
#
# 	statsmodels                        0.12.1
#
# 	sympy                              1.6.2
#
# 	tables                             3.6.1
#
# 	tblib                              1.6.0
#
# 	terminado                          0.9.1
#
# 	testpath                           0.4.4
#
# 	threadpoolctl                      2.1.0
#
# 	tifffile                           2020.10.1
#
# 	toml                               0.10.2
#
# 	toolz                              0.11.1
#
# 	tornado                            6.1
#
# 	tqdm                               4.51.0
#
# 	traitlets                          5.0.5
#
# 	typed-ast                          1.4.1
#
# 	typing-extensions                  3.7.4.3
#
# 	ujson                              4.0.1
#
# 	unicodecsv                         0.14.1
#
# 	urllib3                            1.25.11
#
# 	watchdog                           0.10.3
#
# 	wcwidth                            0.2.5
#
# 	webencodings                       0.5.1
#
# 	Werkzeug                           1.0.1
#
# 	wheel                              0.35.1
#
# 	widgetsnbextension                 3.5.1
#
# 	wikipedia                          1.4.0
#
# 	win-inet-pton                      1.1.0
#
# 	win-unicode-console                0.5
#
# 	wincertstore                       0.2
#
# 	wrapt                              1.11.2
#
# 	xlrd                               1.2.0
#
# 	XlsxWriter                         1.3.7
#
# 	xlwings                            0.20.8
#
# 	xlwt                               1.3.0
#
# 	xmltodict                          0.12.0
#
# 	yapf                               0.30.0
#
# 	youtube-dl                         2020.6.16.1
#
# 	zict                               2.0.0
#
# 	zipp                               3.4.0
#
# 	zope.event                         4.5.0
#
# 	zope.interface                     5.1.2
#
# conda list:
# 	# packages in environment at C:\Users\dev\anaconda3:
#
# 	#
#
# 	# Name                    Version                   Build  Channel
#
# 	_anaconda_depends         2020.07                  py37_0
#
# 	_ipyw_jlab_nb_ext_conf    0.1.0                    py37_0
#
# 	alabaster                 0.7.12                     py_0    conda-forge
#
# 	anaconda                  custom                   py37_1
#
# 	anaconda-client           1.7.2                      py_0    conda-forge
#
# 	anaconda-navigator        1.10.0                   py37_0
#
# 	anaconda-project          0.8.3                      py_0    conda-forge
#
# 	argh                      0.26.2          pyh9f0ad1d_1002    conda-forge
#
# 	argon2-cffi               20.1.0           py37h4ab8f01_2    conda-forge
#
# 	asn1crypto                1.4.0              pyh9f0ad1d_0    conda-forge
#
# 	astroid                   2.4.2            py37hc8dfbb8_1    conda-forge
#
# 	astropy                   4.1              py37hcc03f2d_1    conda-forge
#
# 	async_generator           1.10                       py_0    conda-forge
#
# 	atomicwrites              1.4.0              pyh9f0ad1d_0    conda-forge
#
# 	attrs                     20.2.0             pyh9f0ad1d_0    conda-forge
#
# 	autopep8                  1.5.4              pyh9f0ad1d_0    conda-forge
#
# 	babel                     2.8.0                      py_0    conda-forge
#
# 	backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
#
# 	backports                 1.0                        py_2    conda-forge
#
# 	backports.functools_lru_cache 1.6.1                      py_0    conda-forge
#
# 	backports.shutil_get_terminal_size 1.0.0                      py_3    conda-forge
#
# 	bcrypt                    3.2.0            py37h4ab8f01_1    conda-forge
#
# 	beautifulsoup4            4.9.3              pyhb0f4dca_0    conda-forge
#
# 	bitarray                  1.6.0            py37h4ab8f01_0    conda-forge
#
# 	bkcharts                  0.2                      py37_0
#
# 	blas                      1.0                         mkl
#
# 	bleach                    3.2.1              pyh9f0ad1d_0    conda-forge
#
# 	blosc                     1.20.1               ha925a31_0    conda-forge
#
# 	bokeh                     2.2.3            py37hc8dfbb8_0    conda-forge
#
# 	boto                      2.49.0                     py_0    conda-forge
#
# 	bottleneck                1.3.2            py37h3a3b6f7_2    conda-forge
#
# 	brotli                    1.0.9                ha925a31_3    conda-forge
#
# 	brotlipy                  0.7.0           py37h0013d47_1001    conda-forge
#
# 	bzip2                     1.0.8                he774522_3    conda-forge
#
# 	ca-certificates           2020.6.20            hecda079_0    conda-forge
#
# 	certifi                   2020.6.20        py37hf50a25e_2    conda-forge
#
# 	cffi                      1.14.3           py37hd6b71e5_1    conda-forge
#
# 	chardet                   3.0.4           py37hf50a25e_1008    conda-forge
#
# 	charls                    2.1.0                h33f27b4_2    conda-forge
#
# 	click                     7.1.2              pyh9f0ad1d_0    conda-forge
#
# 	cloudpickle               1.6.0                      py_0    conda-forge
#
# 	clyent                    1.2.2                      py_1    conda-forge
#
# 	colorama                  0.4.4              pyh9f0ad1d_0    conda-forge
#
# 	comtypes                  1.1.7           py37hc8dfbb8_1002    conda-forge
#
# 	conda                     4.9.0            py37hf50a25e_1    conda-forge
#
# 	conda-build               3.20.5           py37hf50a25e_0    conda-forge
#
# 	conda-env                 2.6.0                         1    conda-forge
#
# 	conda-package-handling    1.7.2            py37h6dbccfb_0    conda-forge
#
# 	conda-verify              3.1.1           py37hc8dfbb8_1002    conda-forge
#
# 	console_shortcut          0.1.1                         4
#
# 	contextlib2               0.6.0.post1                py_0    conda-forge
#
# 	cryptography              3.2.1            py37hd8e9650_0    conda-forge
#
# 	curl                      7.71.1               h4b64cdc_8    conda-forge
#
# 	cycler                    0.10.0                     py_2    conda-forge
#
# 	cython                    0.29.21          py37h8e8dfb5_1    conda-forge
#
# 	cytoolz                   0.11.0           py37h4ab8f01_1    conda-forge
#
# 	dask                      2.30.0                     py_0    conda-forge
#
# 	dask-core                 2.30.0                     py_0    conda-forge
#
# 	decorator                 4.4.2                      py_0    conda-forge
#
# 	defusedxml                0.6.0                      py_0    conda-forge
#
# 	diff-match-patch          20200713           pyh9f0ad1d_0    conda-forge
#
# 	distributed               2.30.1           py37h03978a9_0    conda-forge
#
# 	docutils                  0.16             py37hf50a25e_2    conda-forge
#
# 	entrypoints               0.3             py37hc8dfbb8_1002    conda-forge
#
# 	et_xmlfile                1.0.1                   py_1001    conda-forge
#
# 	fastcache                 1.1.0            py37h4ab8f01_2    conda-forge
#
# 	filelock                  3.0.12             pyh9f0ad1d_0    conda-forge
#
# 	flake8                    3.8.4                      py_0    conda-forge
#
# 	flask                     1.1.2              pyh9f0ad1d_0    conda-forge
#
# 	freetype                  2.10.4               h546665d_0    conda-forge
#
# 	fsspec                    0.8.4                      py_0    conda-forge
#
# 	future                    0.18.2           py37hc8dfbb8_2    conda-forge
#
# 	get_terminal_size         1.0.0                h38e98db_0
#
# 	gevent                    20.9.0           py37h4ab8f01_1    conda-forge
#
# 	giflib                    5.2.1                h8d14728_2    conda-forge
#
# 	glob2                     0.7                        py_0    conda-forge
#
# 	gmpy2                     2.1.0b1          py37h2b2749b_1    conda-forge
#
# 	greenlet                  0.4.17           py37h4ab8f01_1    conda-forge
#
# 	h5py                      2.10.0          nompi_py37h23cfb99_105    conda-forge
#
# 	hdf5                      1.10.6          nompi_h89124ea_1110    conda-forge
#
# 	heapdict                  1.0.1                      py_0    conda-forge
#
# 	html5lib                  1.1                pyh9f0ad1d_0    conda-forge
#
# 	icc_rt                    2019.0.0             h0cc432a_1
#
# 	icu                       67.1                 h33f27b4_0    conda-forge
#
# 	idna                      2.10               pyh9f0ad1d_0    conda-forge
#
# 	imagecodecs               2020.5.30        py37hfde3dd5_4    conda-forge
#
# 	imageio                   2.9.0                      py_0    conda-forge
#
# 	imagesize                 1.2.0                      py_0    conda-forge
#
# 	importlib-metadata        2.0.0                      py_1    conda-forge
#
# 	importlib_metadata        2.0.0                         1    conda-forge
#
# 	indeed                    0.0.4                    pypi_0    pypi
#
# 	iniconfig                 1.1.1              pyh9f0ad1d_0    conda-forge
#
# 	intel-openmp              2020.2                      254
#
# 	intervaltree              3.0.2                      py_0    conda-forge
#
# 	ipykernel                 5.3.4            py37h7b7c402_1    conda-forge
#
# 	ipython                   7.19.0           py37heaed05f_0    conda-forge
#
# 	ipython_genutils          0.2.0                      py_1    conda-forge
#
# 	ipywidgets                7.5.1              pyh9f0ad1d_1    conda-forge
#
# 	isort                     5.6.4                      py_0    conda-forge
#
# 	itsdangerous              1.1.0                      py_0    conda-forge
#
# 	jdcal                     1.4.1                      py_0    conda-forge
#
# 	jedi                      0.14.1                   py37_0
#
# 	jinja2                    2.11.2             pyh9f0ad1d_0    conda-forge
#
# 	joblib                    0.17.0                     py_0    conda-forge
#
# 	jpeg                      9d                   h8ffe710_0    conda-forge
#
# 	json5                     0.9.5              pyh9f0ad1d_0    conda-forge
#
# 	jsonschema                3.2.0                      py_2    conda-forge
#
# 	jupyter                   1.0.0                      py_2    conda-forge
#
# 	jupyter_client            6.1.7                      py_0    conda-forge
#
# 	jupyter_console           6.2.0                      py_0    conda-forge
#
# 	jupyter_core              4.6.3            py37hc8dfbb8_2    conda-forge
#
# 	jupyterlab                2.2.9                      py_0    conda-forge
#
# 	jupyterlab_pygments       0.1.2              pyh9f0ad1d_0    conda-forge
#
# 	jupyterlab_server         1.2.0                      py_0    conda-forge
#
# 	jxrlib                    1.1                  hfa6e2cd_2    conda-forge
#
# 	keyring                   21.4.0           py37hc8dfbb8_2    conda-forge
#
# 	kiwisolver                1.3.1            py37h8c56517_0    conda-forge
#
# 	krb5                      1.17.1               hc04afaa_3    conda-forge
#
# 	lazy-object-proxy         1.4.3            py37h4ab8f01_2    conda-forge
#
# 	lcms2                     2.11                 h6a326e1_1    conda-forge
#
# 	lerc                      2.2                  ha925a31_0    conda-forge
#
# 	libaec                    1.0.4                he025d50_1    conda-forge
#
# 	libarchive                3.4.3                h793d221_0    conda-forge
#
# 	libblas                   3.8.0                    20_mkl    conda-forge
#
# 	libcblas                  3.8.0                    20_mkl    conda-forge
#
# 	libclang                  10.0.1          default_hf44288c_1    conda-forge
#
# 	libcurl                   7.71.1               h4b64cdc_8    conda-forge
#
# 	libiconv                  1.16                 he774522_0    conda-forge
#
# 	liblapack                 3.8.0                    20_mkl    conda-forge
#
# 	liblief                   0.10.1               ha925a31_2    conda-forge
#
# 	libllvm9                  9.0.1                hde8ddfe_1    conda-forge
#
# 	libpng                    1.6.37               h1d00b33_2    conda-forge
#
# 	libsodium                 1.0.18               h62dcd97_1    conda-forge
#
# 	libspatialindex           1.9.3                he025d50_3    conda-forge
#
# 	libssh2                   1.9.0                hb06d900_5    conda-forge
#
# 	libtiff                   4.1.0                hc10be44_6    conda-forge
#
# 	libwebp-base              1.1.0                h8ffe710_3    conda-forge
#
# 	libxml2                   2.9.10               h1006b36_2    conda-forge
#
# 	libxslt                   1.1.33               h579f668_1    conda-forge
#
# 	libzopfli                 1.0.3                ha925a31_0    conda-forge
#
# 	llvmlite                  0.34.0           py37h8b575af_2    conda-forge
#
# 	locket                    0.2.0                      py_2    conda-forge
#
# 	lxml                      4.6.1            py37h8ba8a40_0    conda-forge
#
# 	lz4-c                     1.9.2                h62dcd97_2    conda-forge
#
# 	lzo                       2.10              he774522_1000    conda-forge
#
# 	m2-msys2-runtime          2.5.0.17080.65c939c               3
#
# 	m2-patch                  2.7.5                         2
#
# 	m2w64-gcc-libgfortran     5.3.0                         6
#
# 	m2w64-gcc-libs            5.3.0                         7
#
# 	m2w64-gcc-libs-core       5.3.0                         7
#
# 	m2w64-gmp                 6.1.0                         2
#
# 	m2w64-libwinpthread-git   5.0.0.4634.697f757               2
#
# 	markupsafe                1.1.1            py37h0013d47_2    conda-forge
#
# 	matplotlib                3.3.2            py37hc8dfbb8_1    conda-forge
#
# 	matplotlib-base           3.3.2            py37h64d6e1c_1    conda-forge
#
# 	mccabe                    0.6.1                      py_1    conda-forge
#
# 	menuinst                  1.4.16           py37hc8dfbb8_1    conda-forge
#
# 	mistune                   0.8.4           py37h4ab8f01_1002    conda-forge
#
# 	mkl                       2020.2                      256
#
# 	mkl-service               2.3.0            py37h4ab8f01_2    conda-forge
#
# 	mkl_fft                   1.2.0            py37h3a3b6f7_1    conda-forge
#
# 	mkl_random                1.2.0            py37h414f9d2_1    conda-forge
#
# 	mock                      4.0.2            py37hc8dfbb8_1    conda-forge
#
# 	more-itertools            8.6.0              pyhd8ed1ab_0    conda-forge
#
# 	mpc                       1.1.0             h7edee0f_1009    conda-forge
#
# 	mpfr                      4.0.2                h62dcd97_1    conda-forge
#
# 	mpir                      3.0.0             he025d50_1002    conda-forge
#
# 	mpmath                    1.1.0                      py_0    conda-forge
#
# 	msgpack-python            1.0.0            py37h1fb7aa8_2    conda-forge
#
# 	msys2-conda-epoch         20160418                      1
#
# 	multipledispatch          0.6.0                      py_0    conda-forge
#
# 	navigator-updater         0.2.1                    py37_0
#
# 	nbclient                  0.5.1                      py_0    conda-forge
#
# 	nbconvert                 6.0.7            py37hc8dfbb8_2    conda-forge
#
# 	nbformat                  5.0.8                      py_0    conda-forge
#
# 	nest-asyncio              1.4.2              pyhd8ed1ab_0    conda-forge
#
# 	networkx                  2.5                        py_0    conda-forge
#
# 	nltk                      3.4.4                      py_0    conda-forge
#
# 	nose                      1.3.7                   py_1006    conda-forge
#
# 	notebook                  6.1.4            py37hc8dfbb8_1    conda-forge
#
# 	numba                     0.51.2           py37h414f9d2_0    conda-forge
#
# 	numexpr                   2.7.1            py37h414f9d2_3    conda-forge
#
# 	numpy                     1.19.4           py37hd20adf4_0    conda-forge
#
# 	numpy-base                1.18.5           py37hc3f5095_0
#
# 	numpydoc                  1.1.0                      py_1    conda-forge
#
# 	olefile                   0.46               pyh9f0ad1d_1    conda-forge
#
# 	openjpeg                  2.3.1                h57dd2e7_3    conda-forge
#
# 	openpyxl                  3.0.5                      py_0    conda-forge
#
# 	openssl                   1.1.1h               he774522_0    conda-forge
#
# 	packaging                 20.4               pyh9f0ad1d_0    conda-forge
#
# 	pandas                    1.1.4            py37h08fd248_0    conda-forge
#
# 	pandoc                    2.11.0.4             hf4a77e7_0    conda-forge
#
# 	pandocfilters             1.4.2                      py_1    conda-forge
#
# 	paramiko                  2.7.2              pyh9f0ad1d_0    conda-forge
#
# 	parso                     0.5.2                      py_0
#
# 	partd                     1.1.0                      py_0    conda-forge
#
# 	path                      15.0.0           py37hc8dfbb8_1    conda-forge
#
# 	path.py                   12.5.0                        0    conda-forge
#
# 	pathlib2                  2.3.5            py37h03978a9_2    conda-forge
#
# 	pathtools                 0.1.2                      py_1    conda-forge
#
# 	patsy                     0.5.1                      py_0    conda-forge
#
# 	pep8                      1.7.1                      py_0    conda-forge
#
# 	pexpect                   4.8.0              pyh9f0ad1d_2    conda-forge
#
# 	pickleshare               0.7.5                   py_1003    conda-forge
#
# 	pillow                    8.0.1            py37hb71ed58_0    conda-forge
#
# 	pip                       20.2.4                     py_0    conda-forge
#
# 	pkginfo                   1.6.1              pyh9f0ad1d_0    conda-forge
#
# 	pluggy                    0.13.1           py37hf50a25e_3    conda-forge
#
# 	ply                       3.11                       py_1    conda-forge
#
# 	powershell_shortcut       0.0.1                         3
#
# 	prometheus_client         0.8.0              pyh9f0ad1d_0    conda-forge
#
# 	prompt-toolkit            3.0.8                      py_0    conda-forge
#
# 	prompt_toolkit            3.0.8                         0    conda-forge
#
# 	psutil                    5.7.3            py37h0013d47_0    conda-forge
#
# 	ptyprocess                0.6.0                   py_1001    conda-forge
#
# 	py                        1.9.0              pyh9f0ad1d_0    conda-forge
#
# 	py-lief                   0.10.1           py37h8e8dfb5_2    conda-forge
#
# 	pycodestyle               2.6.0              pyh9f0ad1d_0    conda-forge
#
# 	pycosat                   0.6.3           py37h0013d47_1005    conda-forge
#
# 	pycparser                 2.20               pyh9f0ad1d_2    conda-forge
#
# 	pycrypto                  2.6.1           py37h0013d47_1005    conda-forge
#
# 	pycurl                    7.43.0.6         py37hb62a520_0    conda-forge
#
# 	pydocstyle                5.1.1                      py_0    conda-forge
#
# 	pydub                     0.24.1                   pypi_0    pypi
#
# 	pyflakes                  2.2.0              pyh9f0ad1d_0    conda-forge
#
# 	pygments                  2.7.2                      py_0    conda-forge
#
# 	pylint                    2.6.0            py37hc8dfbb8_1    conda-forge
#
# 	pynacl                    1.4.0            py37h230ea1a_2    conda-forge
#
# 	pyodbc                    4.0.30           py37h1834ac0_1    conda-forge
#
# 	pyopenssl                 19.1.0                     py_1    conda-forge
#
# 	pyparsing                 2.4.7              pyh9f0ad1d_0    conda-forge
#
# 	pyphen                    0.9.5                    pypi_0    pypi
#
# 	pyqt                      5.12.3           py37h1834ac0_4    conda-forge
#
# 	pyqt5-sip                 4.19.18                  pypi_0    pypi
#
# 	pyqtchart                 5.12                     pypi_0    pypi
#
# 	pyqtwebengine             5.12.1                   pypi_0    pypi
#
# 	pyreadline                2.1             py37hc8dfbb8_1002    conda-forge
#
# 	pyrsistent                0.17.3           py37h4ab8f01_1    conda-forge
#
# 	pysocks                   1.7.1            py37hf50a25e_2    conda-forge
#
# 	pytables                  3.6.1            py37h14417ae_3    conda-forge
#
# 	pytest                    6.1.2            py37h03978a9_0    conda-forge
#
# 	python                    3.7.8           h60c2a47_1_cpython    conda-forge
#
# 	python-dateutil           2.8.1                      py_0    conda-forge
#
# 	python-jsonrpc-server     0.4.0              pyh9f0ad1d_0    conda-forge
#
# 	python-language-server    0.31.7                   py37_0
#
# 	python-libarchive-c       2.9              py37hf50a25e_2    conda-forge
#
# 	python_abi                3.7                     1_cp37m    conda-forge
#
# 	pytz                      2020.4             pyhd8ed1ab_0    conda-forge
#
# 	pywavelets                1.1.1            py37h3a3b6f7_3    conda-forge
#
# 	pywin32                   228              py37h4ab8f01_0    conda-forge
#
# 	pywin32-ctypes            0.2.0           py37hc8dfbb8_1002    conda-forge
#
# 	pywinpty                  0.5.7            py37hc8dfbb8_1    conda-forge
#
# 	pyyaml                    5.3.1            py37h0013d47_1    conda-forge
#
# 	pyzmq                     19.0.2           py37h453f00a_2    conda-forge
#
# 	qdarkstyle                2.8.1              pyh9f0ad1d_1    conda-forge
#
# 	qt                        5.12.9               hb2cf2c5_0    conda-forge
#
# 	qtawesome                 1.0.1              pyh9f0ad1d_0    conda-forge
#
# 	qtconsole                 4.7.7              pyh9f0ad1d_0    conda-forge
#
# 	qtpy                      1.9.0                      py_0    conda-forge
#
# 	regex                     2020.10.28       py37hcc03f2d_0    conda-forge
#
# 	requests                  2.0.0                    pypi_0    pypi
#
# 	ripgrep                   12.1.1               h301d43c_1    conda-forge
#
# 	rope                      0.18.0             pyh9f0ad1d_0    conda-forge
#
# 	rtree                     0.9.4            py37h804a536_1    conda-forge
#
# 	ruamel_yaml               0.15.80         py37h0013d47_1003    conda-forge
#
# 	scikit-image              0.17.2           py37h08fd248_4    conda-forge
#
# 	scikit-learn              0.23.2           py37heb15398_2    conda-forge
#
# 	scipy                     1.5.3            py37h6db1a17_0    conda-forge
#
# 	seaborn                   0.11.0               h57928b3_1    conda-forge
#
# 	seaborn-base              0.11.0             pyhd8ed1ab_1    conda-forge
#
# 	selenium                  3.141.0                  pypi_0    pypi
#
# 	send2trash                1.5.0                      py_0    conda-forge
#
# 	setuptools                49.6.0           py37hf50a25e_2    conda-forge
#
# 	simplegeneric             0.8.1                      py_1    conda-forge
#
# 	singledispatch            3.4.0.3         pyh9f0ad1d_1001    conda-forge
#
# 	sip                       4.19.24          py37h1834ac0_2    conda-forge
#
# 	six                       1.15.0             pyh9f0ad1d_0    conda-forge
#
# 	snappy                    1.1.8                ha925a31_3    conda-forge
#
# 	snowballstemmer           2.0.0                      py_0    conda-forge
#
# 	sortedcollections         1.2.1              pyh9f0ad1d_0    conda-forge
#
# 	sortedcontainers          2.2.2              pyh9f0ad1d_0    conda-forge
#
# 	soupsieve                 2.0.1                      py_1    conda-forge
#
# 	sphinx                    3.3.0              pyhd8ed1ab_0    conda-forge
#
# 	sphinxcontrib             1.0                      py37_1
#
# 	sphinxcontrib-applehelp   1.0.2                      py_0    conda-forge
#
# 	sphinxcontrib-devhelp     1.0.2                      py_0    conda-forge
#
# 	sphinxcontrib-htmlhelp    1.0.3                      py_0    conda-forge
#
# 	sphinxcontrib-jsmath      1.0.1                      py_0    conda-forge
#
# 	sphinxcontrib-qthelp      1.0.3                      py_0    conda-forge
#
# 	sphinxcontrib-serializinghtml 1.1.4                      py_0    conda-forge
#
# 	sphinxcontrib-websupport  1.2.4              pyh9f0ad1d_0    conda-forge
#
# 	spyder                    4.0.1                    py37_0
#
# 	spyder-kernels            1.8.1                    py37_0
#
# 	sqlalchemy                1.3.20           py37h4ab8f01_0    conda-forge
#
# 	sqlite                    3.33.0               he774522_1    conda-forge
#
# 	statsmodels               0.12.1           py37hda49f71_1    conda-forge
#
# 	sympy                     1.6.2            py37hc8dfbb8_1    conda-forge
#
# 	tbb                       2020.1               he980bc4_0    conda-forge
#
# 	tblib                     1.6.0                      py_0    conda-forge
#
# 	terminado                 0.9.1            py37hc8dfbb8_1    conda-forge
#
# 	testpath                  0.4.4                      py_0    conda-forge
#
# 	threadpoolctl             2.1.0              pyh5ca1d4c_0    conda-forge
#
# 	tifffile                  2020.10.1                  py_0    conda-forge
#
# 	tk                        8.6.10               he774522_1    conda-forge
#
# 	toml                      0.10.2             pyhd8ed1ab_0    conda-forge
#
# 	toolz                     0.11.1                     py_0    conda-forge
#
# 	tornado                   6.1              py37hcc03f2d_0    conda-forge
#
# 	tqdm                      4.51.0             pyh9f0ad1d_0    conda-forge
#
# 	traitlets                 5.0.5                      py_0    conda-forge
#
# 	typed-ast                 1.4.1            py37hfa6e2cd_0    conda-forge
#
# 	typing_extensions         3.7.4.3                    py_0    conda-forge
#
# 	ujson                     4.0.1            py37h1834ac0_1    conda-forge
#
# 	unicodecsv                0.14.1                     py_1    conda-forge
#
# 	urllib3                   1.25.11                    py_0    conda-forge
#
# 	vc                        14.1                 h869be7e_1    conda-forge
#
# 	vs2015_runtime            14.16.27012          h30e32a0_2    conda-forge
#
# 	watchdog                  0.10.3           py37hc8dfbb8_2    conda-forge
#
# 	wcwidth                   0.2.5              pyh9f0ad1d_2    conda-forge
#
# 	webencodings              0.5.1                      py_1    conda-forge
#
# 	werkzeug                  1.0.1              pyh9f0ad1d_0    conda-forge
#
# 	wheel                     0.35.1             pyh9f0ad1d_0    conda-forge
#
# 	widgetsnbextension        3.5.1            py37hc8dfbb8_4    conda-forge
#
# 	wikipedia                 1.4.0                    pypi_0    pypi
#
# 	win_inet_pton             1.1.0            py37hc8dfbb8_1    conda-forge
#
# 	win_unicode_console       0.5             py37hc8dfbb8_1001    conda-forge
#
# 	wincertstore              0.2             py37hc8dfbb8_1005    conda-forge
#
# 	winpty                    0.4.3                         4    conda-forge
#
# 	wrapt                     1.11.2           py37h4ab8f01_1    conda-forge
#
# 	xlrd                      1.2.0              pyh9f0ad1d_1    conda-forge
#
# 	xlsxwriter                1.3.7              pyh9f0ad1d_0    conda-forge
#
# 	xlwings                   0.20.8           py37hc8dfbb8_0    conda-forge
#
# 	xlwt                      1.3.0                      py_1    conda-forge
#
# 	xmltodict                 0.12.0                     py_0    conda-forge
#
# 	xz                        5.2.5                h62dcd97_1    conda-forge
#
# 	yaml                      0.2.5                he774522_0    conda-forge
#
# 	yapf                      0.30.0             pyh9f0ad1d_0    conda-forge
#
# 	youtube-dl                2020.6.16.1              pypi_0    pypi
#
# 	zeromq                    4.3.2                ha925a31_4    conda-forge
#
# 	zfp                       0.5.5                ha925a31_4    conda-forge
#
# 	zict                      2.0.0                      py_0    conda-forge
#
# 	zipp                      3.4.0                      py_0    conda-forge
#
# 	zlib                      1.2.11            h62dcd97_1010    conda-forge
#
# 	zope                      1.0                      py37_1
#
# 	zope.event                4.5.0              pyh9f0ad1d_0    conda-forge
#
# 	zope.interface            5.1.2            py37h4ab8f01_1    conda-forge
#
# 	zstd                      1.4.5                h1f3a1b7_2    conda-forge

# %%
import sys

command_str = '{sys.executable} -m pip freeze'.format(sys=sys)
print(command_str)
# !{command_str}
# Out:
# C:\Users\dev\Anaconda3\envs\tf\python.exe -m pip freeze
# absl-py==0.11.0
# anykeystore==0.2
# apex==0.9.10.dev0
# argon2-cffi @ file:///D:/bld/argon2-cffi_1602546829425/work
# astor @ file:///home/conda/feedstock_root/build_artifacts/astor_1593610464257/work
# astunparse==1.6.3
# async-generator==1.10
# attrs @ file:///home/conda/feedstock_root/build_artifacts/attrs_1599308529326/work
# backcall @ file:///home/conda/feedstock_root/build_artifacts/backcall_1592338393461/work
# backports.functools-lru-cache==1.6.1
# bleach @ file:///home/conda/feedstock_root/build_artifacts/bleach_1600454382015/work
# blis==0.4.1
# boto3 @ file:///home/conda/feedstock_root/build_artifacts/boto3_1604706142628/work
# botocore @ file:///home/conda/feedstock_root/build_artifacts/botocore_1604701913745/work
# brotlipy==0.7.0
# cachetools==4.1.1
# catalogue==1.0.0
# certifi==2020.6.20
# cffi @ file:///D:/bld/cffi_1602537445122/work
# chardet @ file:///D:/bld/chardet_1602255574834/work
# click==7.1.2
# colorama @ file:///home/conda/feedstock_root/build_artifacts/colorama_1602866480661/work
# cryptacular==1.5.5
# cryptography @ file:///D:/bld/cryptography_1604179260895/work
# cymem @ file:///D:/bld/cymem_1604311046446/work
# Cython @ file:///D:/bld/cython_1602367529523/work
# decorator==4.4.2
# defusedxml==0.6.0
# entrypoints @ file:///D:/bld/entrypoints_1602701951950/work/dist/entrypoints-0.3-py2.py3-none-any.whl
# fairseq @ file:///D:/bld/fairseq_1598452928121/work
# ftfy==5.8
# future==0.18.2
# gast @ file:///home/conda/feedstock_root/build_artifacts/gast_1596839682936/work
# google-auth==1.23.0
# google-auth-oauthlib==0.4.2
# google-pasta==0.2.0
# grpcio @ file:///D:/bld/grpcio_1604365793491/work
# h5py @ file:///D:/bld/h5py_1602551956383/work
# hupper==1.10.2
# idna @ file:///home/conda/feedstock_root/build_artifacts/idna_1593328102638/work
# importlib-metadata @ file:///home/conda/feedstock_root/build_artifacts/importlib-metadata_1602263269022/work
# ipykernel @ file:///D:/bld/ipykernel_1602683107803/work/dist/ipykernel-5.3.4-py3-none-any.whl
# ipython @ file:///D:/bld/ipython_1604159743325/work
# ipython-genutils==0.2.0
# ipywidgets @ file:///home/conda/feedstock_root/build_artifacts/ipywidgets_1599554010055/work
# jedi @ file:///D:/bld/jedi_1602395413762/work
# jieba==0.42.1
# Jinja2==2.11.2
# jmespath @ file:///home/conda/feedstock_root/build_artifacts/jmespath_1589369830981/work
# joblib @ file:///home/conda/feedstock_root/build_artifacts/joblib_1601671685479/work
# jsonschema @ file:///home/conda/feedstock_root/build_artifacts/jsonschema_1602551949684/work
# jupyter-client @ file:///home/conda/feedstock_root/build_artifacts/jupyter_client_1598486169312/work
# jupyter-console @ file:///home/conda/feedstock_root/build_artifacts/jupyter_console_1598728807792/work
# jupyter-core @ file:///D:/bld/jupyter_core_1602537572784/work
# jupyterlab-pygments @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_pygments_1601375948261/work
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.2
# Markdown @ file:///home/conda/feedstock_root/build_artifacts/markdown_1603668500820/work
# MarkupSafe @ file:///D:/bld/markupsafe_1602267515311/work
# mistune @ file:///D:/bld/mistune_1602381923828/work
# mkl-service==2.3.0
# murmurhash==1.0.4
# nbclient @ file:///home/conda/feedstock_root/build_artifacts/nbclient_1602859080374/work
# nbconvert @ file:///D:/bld/nbconvert_1603792834939/work
# nbformat @ file:///home/conda/feedstock_root/build_artifacts/nbformat_1602732862338/work
# nest-asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1604290829246/work
# notebook @ file:///D:/bld/notebook_1602720392067/work
# numpy @ file:///D:/bld/numpy_1604603436420/work
# oauthlib==3.1.0
# opt-einsum==3.3.0
# packaging @ file:///home/conda/feedstock_root/build_artifacts/packaging_1589925210001/work
# pandocfilters==1.4.2
# parso @ file:///home/conda/feedstock_root/build_artifacts/parso_1595548966091/work
# PasteDeploy==2.1.1
# pathlib==1.0.1
# pbkdf2==1.3
# pickleshare @ file:///home/conda/feedstock_root/build_artifacts/pickleshare_1602536217715/work
# plac==0.9.6
# plaster==1.0
# plaster-pastedeploy==0.7
# portalocker==2.0.0
# preshed @ file:///D:/bld/preshed_1604316828352/work
# prometheus-client @ file:///home/conda/feedstock_root/build_artifacts/prometheus_client_1590412252446/work
# prompt-toolkit @ file:///home/conda/feedstock_root/build_artifacts/prompt-toolkit_1602524994744/work
# protobuf==3.13.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycparser @ file:///home/conda/feedstock_root/build_artifacts/pycparser_1593275161868/work
# Pygments @ file:///home/conda/feedstock_root/build_artifacts/pygments_1603558917696/work
# pyOpenSSL==19.1.0
# pyparsing==2.4.7
# PyQt5==5.12.3
# PyQt5-sip==4.19.18
# PyQtChart==5.12
# PyQtWebEngine==5.12.1
# pyramid==1.10.4
# pyramid-mailer==0.15.1
# pyreadline @ file:///D:/bld/pyreadline_1602253143868/work
# pyrsistent @ file:///D:/bld/pyrsistent_1602260150376/work
# PySocks==1.6.8
# pythainlp==2.2.4
# python-crfsuite==0.9.7
# python-dateutil==2.8.1
# python3-openid==3.2.0
# pytorch-transformers==1.2.0
# pywin32==228
# pywinpty @ file:///D:/bld/pywinpty_1602377770565/work
# PyYAML==5.3.1
# pyzmq==19.0.2
# qtconsole @ file:///home/conda/feedstock_root/build_artifacts/qtconsole_1599147533948/work
# QtPy==1.9.0
# regex @ file:///D:/bld/regex_1603932378821/work
# repoze.sendmail==4.4.1
# requests @ file:///home/conda/feedstock_root/build_artifacts/requests_1592425495151/work
# requests-oauthlib==1.3.0
# rsa==4.6
# s3transfer @ file:///drone/src/build_artifacts/s3transfer_1602877463089/work
# sacrebleu @ file:///home/conda/feedstock_root/build_artifacts/sacrebleu_1600143243018/work
# sacremoses @ file:///home/conda/feedstock_root/build_artifacts/sacremoses_1588857588528/work
# scipy @ file:///C:/bld/scipy_1604305143982/work
# Send2Trash==1.5.0
# sentencepiece==0.1.94
# six @ file:///home/conda/feedstock_root/build_artifacts/six_1590081179328/work
# spacy @ file:///D:/bld/spacy_1594659295035/work
# SQLAlchemy==1.3.20
# srsly @ file:///D:/bld/srsly_1589222538360/work
# tensorboard==2.3.0
# tensorboard-plugin-wit==1.7.0
# tensorflow==2.3.1
# tensorflow-estimator==2.3.0
# termcolor==1.1.0
# terminado @ file:///D:/bld/terminado_1602679984498/work
# testpath==0.4.4
# thinc @ file:///D:/bld/thinc_1590400575886/work
# tinydb==4.2.0
# torch @ file:///C:/ci/pytorch_1596721630134/work
# tornado @ file:///D:/bld/tornado_1604105307492/work
# tqdm @ file:///home/conda/feedstock_root/build_artifacts/tqdm_1603658198734/work
# traitlets @ file:///home/conda/feedstock_root/build_artifacts/traitlets_1602771532708/work
# transaction==3.0.0
# translationstring==1.4
# urllib3 @ file:///home/conda/feedstock_root/build_artifacts/urllib3_1603125704209/work
# velruse==1.1.1
# venusian==3.0.0
# wasabi @ file:///home/conda/feedstock_root/build_artifacts/wasabi_1600272362626/work
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1600965781394/work
# webencodings==0.5.1
# WebOb==1.8.6
# Werkzeug==1.0.1
# widgetsnbextension @ file:///D:/bld/widgetsnbextension_1603129634666/work
# wincertstore==0.2
# wrapt==1.12.1
# WTForms==2.3.3
# wtforms-recaptcha==0.3.2
# zipp @ file:///home/conda/feedstock_root/build_artifacts/zipp_1603668650351/work
# zope.deprecation==4.4.0
# zope.interface==5.2.0
# zope.sqlalchemy==1.3

# %%
# !jupyter nbextension list
# Out:
# Known nbextensions:
#   config dir: /Users/davebabbitt/.jupyter/nbconfig
#     notebook section
#       jupyter-js-widgets/extension  enabled
#       - Validating: OK

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   cling-cpp11    /Users/davebabbitt/Library/Jupyter/kernels/cling-cpp11
#   octave         /Users/davebabbitt/Library/Jupyter/kernels/octave
#   ir             /Users/davebabbitt/anaconda/share/jupyter/kernels/ir
#   python3        /Users/davebabbitt/anaconda/share/jupyter/kernels/python3

# %%
# !jupyter serverextension list

# %%
# !conda update pandas
# Out:
# Fetching package metadata ...........
# Solving package specifications: .
#
# Package plan for installation in environment /Users/davebabbitt/anaconda:
#
# The following NEW packages will be INSTALLED:
#
#     libcxx:    4.0.1-h579ed51_0
#     libcxxabi: 4.0.1-hebd6815_0
#
# The following packages will be UPDATED:
#
#     pandas:    0.20.3-py35_0    --> 0.21.0-py35h4431f20_1
#
# Proceed ([y]/n)? ^C

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var body = document.body,
#     attribs = body.attributes;
# var command = "notebook_name = " + "'"+attribs['data-notebook-name'].value+"'";
# var command = "notebook_path = " + "'"+attribs['data-notebook-path'].value+"'";
# kernel.execute(command);

# %%
from
notebook_viewer_url = 'https://nbviewer.jupyter.org/github/dbabbitt/notebooks/blob/master/' + notebook_path
notebook_viewer_url
# Out:
# 'https://nbviewer.jupyter.org/github/dbabbitt/notebooks/blob/master/Miscellaneous/ipynb/Troubleshoot.ipynb'

# %%
notebook_path
# Out:
# 'Miscellaneous/ipynb/Troubleshoot.ipynb'

# %%
# %env
# Out:
# {'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.5VFtZakxhY/Render',
#  'CLICOLOR': '1',
#  'CPPFLAGS': '-I/usr/local/opt/openssl/include',
#  'DISPLAY': '/private/tmp/com.apple.launchd.HqGkGuKfdh/org.macosforge.xquartz:0',
#  'GIT_PAGER': 'cat',
#  'HOME': '/Users/davebabbitt',
#  'JPY_PARENT_PID': '966',
#  'LANG': 'en_US.UTF-8',
#  'LDFLAGS': '-L/usr/local/opt/openssl/lib',
#  'LOGNAME': 'davebabbitt',
#  'MPLBACKEND': 'module://ipykernel.pylab.backend_inline',
#  'OCTAVE_EXECUTABLE': '/usr/local/bin/octave-cli',
#  'PAGER': 'cat',
#  'PATH': '/Users/davebabbitt/anaconda2/bin:/usr/local/opt/openssl/bin:/usr/local/opt/openssl/bin:/Users/davebabbitt/anaconda2/bin:/usr/local/git/bin:/Users/davebabbitt/anaconda/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/local/sbin:/opt/local/bin:/Library/TeX/texbin:/opt/X11/bin:/usr/local/opt/openssl/bin:/usr/local/opt/openssl/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/X11/bin:/Library/TeX/texbin',
#  'PKG_CONFIG_PATH': '/usr/local/opt/openssl/lib/pkgconfig',
#  'PWD': '/Users/davebabbitt',
#  'SECURITYSESSIONID': '186a8',
#  'SHELL': '/bin/bash',
#  'SHLVL': '1',
#  'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.kPTHzMBxiD/Listeners',
#  'TERM': 'xterm-color',
#  'TERM_PROGRAM': 'Apple_Terminal',
#  'TERM_PROGRAM_VERSION': '388.1.1',
#  'TERM_SESSION_ID': 'CED36B93-F5DD-4C38-94B0-A3A033684CB4',
#  'TMPDIR': '/var/folders/fr/0vtdl14121v9xzmbhltbh6s00000gn/T/',
#  'USER': 'davebabbitt',
#  'XPC_FLAGS': '0x0',
#  'XPC_SERVICE_NAME': '0',
#  '_': '/Users/davebabbitt/anaconda2/bin/jupyter',
#  '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0'}
